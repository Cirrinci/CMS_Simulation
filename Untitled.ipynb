# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib import colors
from matplotlib.colors import LogNorm
import matplotlib as mpl 
mpl.rcParams["image.origin"] = 'lower'
# mpl.rcParams["image.dpi"] = 200
import os
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import mplhep as hep
plt.style.use(hep.style.CMS)
#from plotting_utils import *
import uproot
import awkward as ak
import dask.dataframe as dd
from dask.distributed import Client

client = Client(dashboard=True)
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/deploy/local.py:161: UserWarning: Setting `dashboard` is discouraged. Please set `dashboard_address` to affect the scheduler (more common) and `worker_dashboard_address` for the worker (less common).
#   warnings.warn(

# %%
input_folder = "/eos/user/r/rdfexp/ecal/cluster/output_deepcluster_dumper/reco_comparison/overlapping_objects_studies/electrons_genmatching"

output_folder = "plots/electrons_gen_matching_v2"
os.makedirs(output_folder, exist_ok=True)
df = pd.HDFStore(f"{input_folder}/Mustache_126X_mcRun3_2023_v1.hdf5", "r")["df"]
df.rename(columns={"output_object.csv":"genpart_index"}, inplace=True)
df = df.iloc[:-1]

#df = dd.from_pandas(df, npartitions=4)

# %%
list(df.columns)
# Out:
# ['genpart_index',
#  'elematched',
#  'phomatched',
#  'ele_index',
#  'pho_index',
#  'deltaR_genPart_ele',
#  'deltaR_genPart_pho',
#  'calomatched',
#  'caloindex',
#  'sc_matched',
#  'sc_index',
#  'seed_index',
#  'en_seed',
#  'et_seed',
#  'en_seed_calib',
#  'et_seed_calib',
#  'seed_eta',
#  'seed_phi',
#  'seed_iz',
#  'sc_eta',
#  'sc_phi',
#  'sc_swissCross',
#  'sc_r9',
#  'sc_sigmaIetaIeta',
#  'sc_sigmaIetaIphi',
#  'sc_sigmaIphiIphi',
#  'sc_e5x5',
#  'sc_swissCross_f5x5',
#  'sc_r9_f5x5',
#  'sc_sigmaIetaIeta_f5x5',
#  'sc_sigmaIetaIphi_f5x5',
#  'sc_sigmaIphiIphi_f5x5',
#  'sc_e5x5_f5x5',
#  'ele_eta',
#  'ele_phi',
#  'ele_energy',
#  'ele_et',
#  'ele_ecalEnergy',
#  'ele_ecalSCEnergy',
#  'ele_scRawEnergy',
#  'ele_scRawESEnergy',
#  'ele_SCfbrem',
#  'ele_tracfbrem',
#  'ele_e5x5',
#  'ele_e3x3',
#  'ele_sigmaIEtaIEta',
#  'ele_sigmaIEtaIPhi',
#  'ele_sigmaIPhiIPhi',
#  'ele_ecalIso03',
#  'ele_trkIso03',
#  'ele_hcalIso03',
#  'ele_pfChargedHadronIso',
#  'ele_pfNeutralHadronIso',
#  'ele_pfPhotonIso',
#  'ele_HoE',
#  'ele_deltaEtaSeedClusterAtCalo',
#  'ele_deltaPhiSeedClusterAtCalo',
#  'ele_deltaEtaEleClusterAtCalo',
#  'ele_deltaPhiEleClusterAtCalo',
#  'ele_egmMVAElectronIDtight',
#  'ele_egmMVAElectronIDloose',
#  'ele_egmMVAElectronIDmedium',
#  'ele_isEcalDriven',
#  'ele_isTrackerDriven',
#  'ncls_sel',
#  'ncls_sel_true',
#  'ncls_sel_false',
#  'ncls_true',
#  'ncls_tot',
#  'ncls_missing',
#  'ele_nclsRefinedSC',
#  'ele_nclsEcalSC',
#  'ele_passConversionVeto',
#  'ele_nOverlapPhotons',
#  'ele_overlapPhotonIndices',
#  'ele_trackPAtCalo',
#  'ele_trackDeltaEtaIn',
#  'ele_trackDeltaPhiIn',
#  'ele_trackDeltaEtaSeedClusterAtCalo',
#  'ele_trackDeltaEtaEleClusterAtCalo',
#  'ele_trackDeltaPhiEleClusterAtCalo',
#  'ele_misHits',
#  'ele_nAmbiguousGsfTracks',
#  'ele_trackFbrem',
#  'ele_superClusterFbrem',
#  'ele_dz',
#  'ele_dxy',
#  'ele_dzError',
#  'ele_dxyError',
#  'ele_isEBEEGap',
#  'ele_isEBEtaGap',
#  'ele_isEBPhiGap',
#  'ele_isEEDeeGap',
#  'ele_isEERingGap',
#  'pho_eta',
#  'pho_phi',
#  'pho_energy',
#  'pho_et',
#  'pho_scRawEnergy',
#  'pho_e5x5',
#  'pho_e3x3',
#  'pho_sigmaIEtaIEta',
#  'pho_sigmaIEtaIPhi',
#  'pho_sigmaIPhiIPhi',
#  'pho_HoE',
#  'cl2_en',
#  'cl3_en',
#  'cl4_en',
#  'en_sc_raw',
#  'et_sc_raw',
#  'en_sc_calib',
#  'et_sc_calib',
#  'sc_etaWidth',
#  'sc_phiWidth',
#  'true_energy_cls',
#  'sel_true_energy_cls',
#  'missing_energy_cls',
#  'sel_false_energy_cls',
#  'selected_energy_cls',
#  'calo_en_gen',
#  'calo_et_gen',
#  'calo_en_sim',
#  'calo_et_sim',
#  'calo_geneta',
#  'calo_genphi',
#  'calo_simeta',
#  'calo_simphi',
#  'calo_genpt',
#  'genpart_en',
#  'genpart_et',
#  'genpart_eta',
#  'genpart_phi',
#  'genpart_pt',
#  'nVtx',
#  'rho',
#  'obsPU',
#  'truePU',
#  'eventId',
#  'runId']

# %%
def calculate_mean_std(column):
    mean = column.mean()
    std = column.std()
    return pd.Series({'mean': mean, 'std': std})

grouped_stats = df.groupby(['runId', 'eventId'])['genpart_et'].apply(calculate_mean_std)

# Display the result
print(grouped_stats)
# Out:
# runId    eventId
# 1.0      1.0      mean    268.451014
#                   std     135.683647
#          2.0      mean    312.736193
#                   std     116.624841
#          3.0      mean    116.826430
#                              ...
# 10000.0  48.0     std     139.090889
#          49.0     mean    287.384393
#                   std     162.700055
#          50.0     mean    179.264867
#                   std     133.208210
# Name: genpart_et, Length: 1000000, dtype: float64

# %%
def calculate_deltaR(group):
    # Calculate deltaR for pairs (1, 2), (3, 4), (5, 6), and (7, 8) within each group
    data = []
    for i in range(0, 7, 2):  # Iterate over indices 0, 2, 4, and 6
        dr_diff = np.sqrt((group.iloc[i]['seed_eta'] - group.iloc[i+1]['seed_eta'])**2
                           +(group.iloc[i]['seed_phi'] - group.iloc[i+1]['seed_phi'])**2)
        eta_mean=(group.iloc[i]['seed_eta'] + group.iloc[i+1]['seed_eta'])/2
        phi_mean=(group.iloc[i]['seed_phi'] + group.iloc[i+1]['seed_phi'])/2
        data.append({
            'deltaR': dr_diff,
            'eta_mean': eta_mean,
            'phi_mean':phi_mean,
            "energy1": group.iloc[i]['et_seed'],
            'energy2':group.iloc[i+1]['et_seed'],
            'ele_index1':group.iloc[i]['ele_index'],
            'ele_index2':group.iloc[i+1]['ele_index'],
            'ele_matched1':group.iloc[i]['elematched'],
            'ele_matched2':group.iloc[i+1]['elematched'],
        })
        
    return pd.DataFrame(data)

grouped_deltas = df.groupby(['runId', 'eventId']).apply(calculate_deltaR, meta={
            'deltaR':'f8',
            'eta_mean': 'f8',
            'phi_mean': 'f8',
            "energy1":'f8',
            'energy2':'f8',
            'ele_index1':'f8',
            'ele_index2':'f8',
            'ele_matched1':'f8',
            'ele_matched2':'f8',
        }).compute()
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/client.py:3141: UserWarning: Sending large graph of size 4.11 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2024-04-26 11:23:40,169 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/protocol/core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/msgpack/__init__.py", line 38, in packb
#     return Packer(**kwargs).pack(o)
#   File "msgpack/_packer.pyx", line 294, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 300, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 297, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 202, in msgpack._cmsgpack.Packer._pack
# ValueError: bytes object is too large
# 2024-04-26 11:23:40,242 - distributed.comm.utils - ERROR - bytes object is too large
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/comm/utils.py", line 55, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/protocol/core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/msgpack/__init__.py", line 38, in packb
#     return Packer(**kwargs).pack(o)
#   File "msgpack/_packer.pyx", line 294, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 300, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 297, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 202, in msgpack._cmsgpack.Packer._pack
# ValueError: bytes object is too large
# 2024-04-26 11:23:40,260 - distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/comm/tcp.py", line 271, in write
#     frames = await to_frames(
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/comm/utils.py", line 70, in to_frames
#     return await offload(_to_frames)
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/utils.py", line 1519, in run_in_executor_with_context
#     return await loop.run_in_executor(
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/utils.py", line 1520, in <lambda>
#     executor, lambda: context.run(func, *args, **kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/comm/utils.py", line 55, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/protocol/core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/msgpack/__init__.py", line 38, in packb
#     return Packer(**kwargs).pack(o)
#   File "msgpack/_packer.pyx", line 294, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 300, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 297, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 202, in msgpack._cmsgpack.Packer._pack
# ValueError: bytes object is too large
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# /tmp/ipykernel_531/3919176440.py in <module>
#      21     return pd.DataFrame(data)
#      22
# ---> 23 grouped_deltas = df.groupby(['runId', 'eventId']).apply(calculate_deltaR, meta={
#      24             'deltaR':'f8',
#      25             'eta_mean': 'f8',
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    2246                         else:
#    2247                             raise exception.with_traceback(traceback)
# -> 2248                         raise exc
#    2249                     if errors == "skip":
#    2250                         bad_keys.add(key)
#
# CancelledError: ('calculate_deltaR-c829ffde1ee4a88637a4cb1e79b767ce', 3)

# %%
def DeltaPhi(phi1, phi2):
    dphi = phi1 - phi2
    dphi[dphi > np.pi] -= 2 * np.pi
    dphi[dphi < -np.pi] += 2 * np.pi
    return dphi

def calculate_deltaR(group):
    # Calculate deltaR for pairs (1, 2), (3, 4), (5, 6), and (7, 8) within each group
    
    # Extract relevant columns
    eta = group['seed_eta'].values
    phi = group['seed_phi'].values
    et_seed = group['et_seed'].values
    ele_index = group['ele_index'].values
    elematched = group['elematched'].values
    
    # Calculate differences and means
    eta_diff = eta[::2] - eta[1::2]
    dphi = (phi[::2] - phi[1::2])
    dphi[dphi > np.pi] -= 2 * np.pi
    dphi[dphi < -np.pi] += 2 * np.pi
    dr_diff = np.sqrt(eta_diff**2 + dphi**2)
    eta_mean = (eta[::2] + eta[1::2]) / 2
    phi_mean = (phi[::2] + phi[1::2]) / 2
    
    # Create DataFrame with calculated values
    data = {
        'deltaR': dr_diff,
        'eta_mean': eta_mean,
        'phi_mean': phi_mean,
        "energy1": et_seed[::2],
        'energy2': et_seed[1::2],
        'ele_index1': ele_index[::2],
        'ele_index2': ele_index[1::2],
        'ele_matched1': elematched[::2],
        'ele_matched2': elematched[1::2],
    }
    
    return pd.DataFrame(data)

grouped_deltas = df.groupby(['runId', 'eventId']).apply(calculate_deltaR)
grouped_deltas.to_csv('grouped_deltas.csv', index=False)  # Specify index=False to exclude the index from the CSV file

print(grouped_deltas)
# Out:
#                      deltaR  eta_mean  phi_mean     energy1     energy2  \
# runId   eventId
# 1.0     1.0     0  0.551035 -1.984344 -0.376403  150.656604  291.528709
#                 1  0.317344 -0.022032  1.114900  221.470503  402.139933
#                 2  0.262934  0.324093 -2.083485    4.298464  292.160055
#                 3  0.341636  2.593414 -2.771620  350.166776  308.337960
#         2.0     0  0.123358 -1.784437  1.548910  435.449147  155.101249
# ...                     ...       ...       ...         ...         ...
# 10000.0 49.0    3  0.086030  2.338423  0.941371  205.650891  243.180359
#         50.0    0  0.654432 -2.465183  1.022313  198.366234  232.496569
#                 1  0.164208 -1.336543 -2.860785  100.919535   79.039105
#                 2  0.471655  0.846416 -0.186096   22.279188  128.514446
#                 3  0.570831  2.116067  2.016804  118.110798  457.659610
#
#                    ele_index1  ele_index2  ele_matched1  ele_matched2
# runId   eventId
# 1.0     1.0     0         6.0         3.0           1.0           1.0
#                 1         5.0         0.0           1.0           1.0
#                 2         7.0         4.0           1.0           1.0
#                 3         1.0         2.0           1.0           1.0
#         2.0     0         1.0         7.0           1.0           1.0
# ...                       ...         ...           ...           ...
# 10000.0 49.0    3         4.0         3.0           1.0           1.0
#         50.0    0         2.0         1.0           1.0           1.0
#                 1         6.0         5.0           1.0           1.0
#                 2         7.0         4.0           1.0           1.0
#                 3         3.0         0.0           1.0           1.0
#
# [2000000 rows x 9 columns]

# %%
valid_energy_mask = (grouped_deltas['energy1'] != -999.0) | (grouped_deltas['energy2'] != -999)
grouped_deltas = grouped_deltas[valid_energy_mask]

# %% [markdown]
# # Event same ele_index

# %%
grouped_deltas = pd.read_csv('grouped_deltas.csv')
valid_energy_mask = (grouped_deltas['energy1'] != -999.0) & (grouped_deltas['energy2'] != -999)
grouped_deltas = grouped_deltas[valid_energy_mask]

# %%
same_ele_index_mask = grouped_deltas['ele_index1'] == grouped_deltas['ele_index2']
same_ele_events = grouped_deltas[same_ele_index_mask]
print(same_ele_events)
# Out:
#            deltaR  eta_mean  phi_mean     energy1     energy2  ele_index1  \
# 8        0.397619 -2.717630  1.000286   66.707661   19.524207         4.0
# 11       0.000000  2.353917 -2.897435  175.723073  175.723073         0.0
# 14       0.432350  1.458462  0.090822  382.177092   11.770871         0.0
# 15       0.662526  2.199717 -0.586024  258.266043  152.912096         1.0
# 20       0.059364 -1.860363 -0.283891  475.390957  156.890899         0.0
# ...           ...       ...       ...         ...         ...         ...
# 1999972  0.046820 -1.928997  0.769187  145.861126  335.202514         2.0
# 1999980  0.000000 -2.938437  0.045695  155.999824  155.999824         4.0
# 1999985  0.262245 -0.308727 -1.731144   49.076095   65.244974         4.0
# 1999988  0.539587 -2.785031  1.413656  340.132350   38.145742         0.0
# 1999992  0.260114 -2.142464  2.396342  489.236253  354.589285         1.0
#
#          ele_index2  ele_matched1  ele_matched2
# 8               4.0           1.0           1.0
# 11              0.0           1.0           1.0
# 14              0.0           1.0           1.0
# 15              1.0           1.0           1.0
# 20              0.0           1.0           1.0
# ...             ...           ...           ...
# 1999972         2.0           1.0           1.0
# 1999980         4.0           1.0           1.0
# 1999985         4.0           1.0           1.0
# 1999988         0.0           1.0           1.0
# 1999992         1.0           1.0           1.0
#
# [372166 rows x 9 columns]

# %%
max_energy1 = (same_ele_events['energy1']/same_ele_events['energy2']).max()
min_energy1 = same_ele_events['energy1'].min()

# Print the maximum and minimum values
print("Maximum energy1:", max_energy1)
print("Minimum energy1:", min_energy1)
# Out:
# Maximum energy1: 606.2472298557467
# Minimum energy1: 0.7895638566125228

# %%
fig, ax = plt.subplots(1,1,dpi=100, figsize=(7, 5))

A,xedges,yedges  = np.histogram2d(same_ele_events.phi_mean ,same_ele_events.eta_mean,bins=(150, 150), range=((-np.pi,np.pi),(-3,3)))

s = 1#np.expand_dims(np.sum(A, axis=-1), axis=1)
a = A/s
X, Y = np.meshgrid(xedges, yedges)
I = ax.pcolormesh(X, Y, a.T, norm=LogNorm(), cmap="inferno")

fig.colorbar(I, ax=ax, label="density")
ax.set_ylabel("$\eta^{mean}_{seed}$", fontsize=14)
ax.set_xlabel("$\phi^{mean}_{seed}$", fontsize=14)
plt.title('Mask same electron',fontsize=14)
hep.cms.label(llabel="Simulation", rlabel="GEN-matched", loc=0, ax=ax,fontsize=11)
plt.tight_layout()
plt.savefig('plots/eta_phi.png')
plt.show()
fig, ax = plt.subplots(1,1,dpi=100, figsize=(7, 5))

A,xedges,yedges  = np.histogram2d(same_ele_events.phi_mean ,same_ele_events.eta_mean,bins=(150, 150), range=((-np.pi,np.pi),(-3,3)))

s = np.expand_dims(np.sum(A, axis=-1), axis=1)
a = A/s
X, Y = np.meshgrid(xedges, yedges)
I = ax.pcolormesh(X, Y, a.T, norm=LogNorm(), cmap="inferno")

fig.colorbar(I, ax=ax, label="Profiled density")
ax.set_ylabel("$\eta^{mean}_{seed}$", fontsize=14)
ax.set_xlabel("$\phi^{mean}_{seed}$", fontsize=14)
plt.title('Mask same electron',fontsize=14)
hep.cms.label(llabel="Simulation", rlabel="GEN-matched", loc=0, ax=ax,fontsize=11)
plt.tight_layout()
plt.savefig('plots/eta_phi_prof.png')

# %%
energy_ratio = same_ele_events['energy1'] / same_ele_events['energy2']
energy_ratio[same_ele_events['energy1'] < same_ele_events['energy2']] = same_ele_events['energy2'] / same_ele_events['energy1']

plt.hist(energy_ratio, bins=50, edgecolor='black', log=True)  # Set log=True
plt.xlabel('E1/E2')
plt.ylabel('Frequency')
plt.title('Histogram of energy ratio (E1/E2) with logarithmic scale')
plt.savefig('plots/hist_e1-e2.png')
plt.show()
print('min energyratio: ', energy_ratio.min())
# Out:
# min energyratio:  1.0

# %%
fig, ax = plt.subplots(1,1,dpi=100, figsize=(7, 5))

A,xedges,yedges  = np.histogram2d(same_ele_events.eta_mean ,same_ele_events.energy1,bins=(150, 150), range=((-3,3),(0,1050)))

s = 1#np.expand_dims(np.sum(A, axis=-1), axis=1)
a = A/s
X, Y = np.meshgrid(xedges, yedges)
I = ax.pcolormesh(X, Y, a.T, norm=LogNorm(), cmap="inferno")

fig.colorbar(I, ax=ax, label="Ncls-profiled density")
ax.set_xlabel("$\eta^{mean}_{seed}$", fontsize=14)
ax.set_ylabel("Energy1", fontsize=14)
plt.title('Mask same electron')
hep.cms.label(llabel="Simulation", rlabel="GEN-matched", loc=0, ax=ax)
plt.tight_layout()
plt.savefig('plots/e1_eta.png')

# %%
fig, ax = plt.subplots(1,1,dpi=100, figsize=(7, 5))

A,xedges,yedges  = np.histogram2d(same_ele_events.eta_mean ,same_ele_events.energy2,bins=(150, 150), range=((-3,3),(0,1050)))

s = 1#np.expand_dims(np.sum(A, axis=-1), axis=1)
a = A/s
X, Y = np.meshgrid(xedges, yedges)
I = ax.pcolormesh(X, Y, a.T, norm=LogNorm(), cmap="inferno")

fig.colorbar(I, ax=ax, label="Ncls-profiled density")
ax.set_xlabel("$\eta^{mean}_{seed}$", fontsize=14)
ax.set_ylabel("Energy2", fontsize=14)
plt.title('Mask same electron')
hep.cms.label(llabel="Simulation", rlabel="GEN-matched", loc=0, ax=ax)
plt.tight_layout()
plt.savefig('plots/e2_eta.png')

# %%
fig, ax = plt.subplots(1,1,dpi=100, figsize=(7, 5))

A,xedges,yedges  = np.histogram2d(same_ele_events.eta_mean ,energy_ratio,bins=(150, 150), range=((-3,3),(0,400)))

s = 1#np.expand_dims(np.sum(A, axis=-1), axis=1)
a = A/s
X, Y = np.meshgrid(xedges, yedges)
I = ax.pcolormesh(X, Y, a.T, norm=LogNorm(), cmap="inferno")

fig.colorbar(I, ax=ax, label="Ncls-profiled density")
ax.set_xlabel("$\eta^{mean}_{seed}$", fontsize=14)
ax.set_ylabel("E1/E2", fontsize=14)
plt.title('Mask same electron')
hep.cms.label(llabel="Simulation", rlabel="GEN-matched", loc=0, ax=ax)
plt.tight_layout()
plt.savefig('plots/e1-e2_eta.png')

# %%
total_events = len(grouped_deltas)

same_ele_index_events = grouped_deltas[grouped_deltas['ele_index1'] == grouped_deltas['ele_index2']]
same_ele_index_count = len(same_ele_index_events)
percentage_same_ele_index = (same_ele_index_count / total_events) * 100

print(f"Percentage of events with the same ele_index: {percentage_same_ele_index:.2f}%")
# Out:
# Percentage of events with the same ele_index: 19.59%

# %%
eta_mean_range = (1.4, 1.6)

filtered_events = grouped_deltas[(grouped_deltas['eta_mean'] >= eta_mean_range[0]) & 
                                 (grouped_deltas['eta_mean'] <= eta_mean_range[1]) &
                                 (grouped_deltas['ele_index1'] == grouped_deltas['ele_index2'])]

total_events_eta_range = len(grouped_deltas[(grouped_deltas['eta_mean'] >= eta_mean_range[0]) & 
                                             (grouped_deltas['eta_mean'] <= eta_mean_range[1])])

same_ele_eta_range_count = len(filtered_events)
percentage_same_ele_index_eta_range = (same_ele_eta_range_count / total_events_eta_range) * 100
print(f"Percentage of events with the same ele_index in the range eta {eta_mean_range}: {percentage_same_ele_index_eta_range:.2f}%"
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: unexpected EOF while parsing (983013716.py, line 12)

# %%
plt.figure(figsize=(8, 6))  
plt.hist(same_ele_events['deltaR'], bins=30, edgecolor='black')
plt.xlabel('deltaR', fontsize=14)  
plt.ylabel('Frequency', fontsize=14)  
plt.title('Histogram of deltaR for all events', fontsize=16)  
plt.xticks(fontsize=12) 
plt.yticks(fontsize=12) 
plt.tight_layout() 
plt.savefig('plots/deltaR_histogram.png')
plt.show()

# %%
print('delta r max: ',same_ele_events['deltaR'].max())
# Out:
# delta r max:  0.9109802460250596

# %%
def fraction_same_ele_index_vs_deltaR(num_intervals):
    deltaR_max = same_ele_events['deltaR'].max()
    deltaR_values, y = np.linspace(0, deltaR_max, num_intervals + 1, retstep=True)

    fraction_list = []
    yer = []

    for i in range(len(deltaR_values) - 1):
        lower_bound = deltaR_values[i]
        upper_bound = deltaR_values[i + 1]
        
        mask = (same_ele_events['deltaR'] > lower_bound) & (same_ele_events['deltaR'] <= upper_bound)
        mask2 = (grouped_deltas['deltaR'] > lower_bound) & (grouped_deltas['deltaR'] <= upper_bound)

        n1 = len(same_ele_events[mask])
        ntot = len(grouped_deltas[mask2])
        if ntot == 0:
            ntot = 1
        fraction = n1 / ntot
        fraction_list.append(fraction)
        yer.append(np.sqrt(n1 + n1**2 / ntot) / ntot)

    plt.figure(figsize=(8,6))  # Larger figsize
    plt.errorbar(deltaR_values[:-1] + y / 2, fraction_list, xerr=np.ones(num_intervals) * y / 2, yerr=yer, fmt='none')
    #plt.scatter(deltaR_values[:-1] + y / 2, fraction_list)
    plt.xlabel('Delta R', fontsize=14)
    plt.ylabel('Fraction of events with same ele_index', fontsize=14) 
    plt.title('Fraction of events with same ele_index vs. Delta R', fontsize=16)  
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('plots/fraction_deltaR.png')
    plt.show()

num_intervals = 20
fraction_same_ele_index_vs_deltaR(num_intervals)
